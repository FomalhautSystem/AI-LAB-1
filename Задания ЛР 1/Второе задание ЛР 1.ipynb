# %%
import os

with open("Venochek.txt", "w") as file:
    file.write("И плывет веночек вдоль ночной воды\n")
    file.write("Одинокая стою на берегу\n")
    file.write("Вижу отражение своей мечты\n")
    file.write("Но найти её на небе не могу\n")

print("Файл создан и данные записаны.\n")

with open("Venochek.txt", "r") as file:
    content = file.read()

print("Содержимое файла:")
print(content)

if os.path.exists("Venochek.txt"):
    print("Файл существует.")
else:
    print("Веночек не найден.")

os.remove("Venochek.txt")
print("Веночек удалён.")
