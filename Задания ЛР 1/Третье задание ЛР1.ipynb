# %%
print("Список всех магических команд:")
# %lsmagic

# %%
print("Измерение времени выполнения для 1 строки: ")
# %time sum(range(1000000))

# %%
# %%timeit
print("Измерение времени выполнения для всей ячейки: ")
sum(range(1000000))

# %%
# %%writefile script.py
print("Это скрипт")
print("Ошибок нет")

# %%
print("Список файлов текущей дериктории: ")
# %ls

# %%
print("История команд: ")
# %history

# %%
print("Сейчас используется пайтон: ")
# !which python
# Out:
# Сейчас используется пайтон:
# /usr/local/bin/python

# %%
# !mkdir test_folder
# !ls

# %%
# !ls
